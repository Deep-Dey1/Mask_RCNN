# %% [markdown]
# <a href="https://colab.research.google.com/github/Deep-Dey1/Mask_RCNN/blob/master/yolov11n_Fire_detection_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="TlttXJ1x7t9yw7lrTWEg")
project = rf.workspace("-jwzpw").project("continuous_fire")
version = project.version(6)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to continuous_fire-6 in yolov11:: 100%|██████████| 5030/5030 [00:00<00:00, 9999.41it/s]

# %%
# !yolo task=detect mode=train model=/content/yolo11n.pt data=/content/continuous_fire-6/data.yaml epochs=150 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
